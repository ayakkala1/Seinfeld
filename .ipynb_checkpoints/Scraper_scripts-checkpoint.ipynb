# %% [markdown]
# # Seinfeld Script Scraper
#
# ### URL : http://www.seinology.com/scripts.shtml

# %%
from lxml import html
from json import dump,loads
from requests import get
import json
import re
from dateutil import parser as dateparser
from time import sleep
import pandas as pd
from itertools import chain
import numpy as np
from bs4 import BeautifulSoup
import urllib.request
import datetime

# %%
def parse_sein_url(url):
    texts = ""
    response_ep = get(url)
    cleaned_response_ep = response_ep.text.replace('\x00', "")
    parser_ep = html.fromstring(cleaned_response_ep)
    return parser_ep.xpath(".//p//font//text()")

def clean_text(text):
    episode_info = {}
    series_text = pd.Series(text).str.replace("\xa0","")
    clean_text = series_text.str.replace("(\n|\t)","")
    episode_info["title"] = clean_text[0]
    episode_info["chronology"] = clean_text[1]
    episode_info["date"] = clean_text[2]
    episode_info["etc"] = clean_text[3]
    if episode_info["etc"] != '':
        if episode_info["title"] == 'Episode 45 - The Wallet (1)':
            episode_info["writer"] = clean_text[6]
            episode_info["director"] = clean_text[7]
        elif episode_info["title"] == "Originally Transcribed by unknown":
            episode_info["title"] = clean_text[2]
            episode_info["chronology"] = clean_text[3]
            episode_info["date"] = clean_text[4]
            episode_info["etc"] = ''
            episode_info["writer"] = clean_text[5]
            episode_info["director"] = clean_text[6]
        else:
            episode_info["writer"] = clean_text[5]
            episode_info["director"] = clean_text[6]
    else:
        episode_info["writer"] = clean_text[4]
        episode_info["director"] = clean_text[5]
    return episode_info

def extract_text(text):
    series_text = pd.Series(text)
    clean_text = series_text.str.replace("(\xa0|\n|\t)","")
    clean_text = clean_text.str.replace("\x91","'")
    clean_text = clean_text.str.replace("\x92","'")
    clean_text = clean_text.str.replace("\x93",'""')
    clean_text = clean_text.str.replace("\x94",'""')
    clean_text = clean_text.str.replace("\x96",'-')
    start_script = clean_text[clean_text.str.contains("====")].index[0] + 1
    lines = clean_text.iloc[start_script:]
    clean_lines = lines[lines != ""]
    return clean_lines.tolist()

def extract_cast_lines(a_list,cast_member):
    cast_member = cast_member.upper()
    if cast_member == "KRAMER":
        return [i for i in a_list if "{0}:".format(cast_member) in i or "KESSLER:" in i]
    elif cast_member == "ETC":
        return [i for i in a_list if ("GEORGE:" not in i) and ("ELAINE:") not in i and ("JERRY:" not in i) and ("KRAMER:" not in i) and ("KESSLER:" not in i) and ("NEWMAN:" not in i)]
    else:
        return [i for i in a_list if "{0}:".format(cast_member) in i]

# %%
def clean_data(series):
    series = series.str.lower()
    series = series.str.replace("\n","")
    series = series.str.replace("\r","")
    series = series.str.replace("-"," ")
    series = series.str.replace("[^\w\s]"," ")
    return series

def explode(df, lst_cols, fill_value=''):
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
        
    idx_cols = df.columns.difference(lst_cols)

    lens = df[lst_cols[0]].str.len()

    if (lens > 0).all():
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]

# %%
response = get("http://www.seinology.com/scripts-english.shtml")
cleaned_response = response.text.replace('\x00', "")

parser = html.fromstring(cleaned_response)

episodes = {}
regexp = re.compile(r'\d.shtml')
for i in parser.xpath('.//a'):
    try:
        if regexp.search(i.attrib["href"]):
            if i.text == None:
                episodes[i.xpath(".//font")[0].text] = "http://www.seinology.com/{0}".format(i.attrib["href"])
            else:
                episodes[i.text] = "http://www.seinology.com/{0}".format(i.attrib["href"])
    except:
        x = 1
        
df = pd.DataFrame(list(episodes.items()),columns=["Episode","URL"])

# %%
df["text"] = df["URL"].apply(parse_sein_url)
text_info = pd.DataFrame(df["text"].apply(clean_text))["text"].apply(pd.Series)

# %%
dat = df.join(text_info)
dat.loc[82,"writer"] = "Larry Charles"
dat.loc[81:82,"director"] = "Tom Cherones"

# %%
dat["lines"] = dat["text"].apply(extract_text)

# %%
dat["jerry_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"JERRY"))
dat["elaine_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"ELAINE"))
dat["kramer_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"KRAMER"))
dat["george_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"GEORGE"))
dat["newman_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"NEWMAN"))
dat["etc_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"etc"))

# %%
dat["date"] = dat["date"].str.replace("Broadcast date: ","")

# %%
dat["date"] = pd.to_datetime(dat['date'])

# %%
dat[["code","season","episode"]] = dat["chronology"].str.split("(season|episode[^ ]*) ",expand=True).drop([1,3],axis=1)

# %%
dat["code"] = dat["code"].str.replace("(pc:|,)","")

# %%
dat["season"] = dat["season"].str.replace("(season |,)","")

# %%
dat["writer"] = (dat["writer"].
                 str.replace("(Written By |Written by |Written by: )","").
                 str.replace("( and |, | / Story By | & )",",").
                 str.split(","))

# %%
dat["director"] = (dat["director"].str.replace("(Directed By |Directed by |Story by )","").
                 str.replace("( & |,| and |, |Part 2 Written by )",",").
                 str.split(","))

# %%
explode_dir = explode(dat,"director")
explode_writ = explode(dat,"writer")

# %%
explode_writ["writer"].str.strip().value_counts().head()
# Out:
# Larry David       58
# Peter Mehlman     21
# Larry Charles     20
# Jerry Seinfeld    18
# Alec Berg         14
# Name: writer, dtype: int64

# %%
explode_dir["director"].str.strip().value_counts().head()
# Out:
# Andy Ackerman         84
# Tom Cherones          77
# Larry David            3
# Peter Mehlman          3
# David Owen Trainor     2
# Name: director, dtype: int64

# %%
dat.loc[0,"season"] = "Pilot"

# %%
dat["season"] = dat["season"].str.strip()

# %%
dat["season"].value_counts().sort_values("index")
# Out:
# Pilot     1
# 1         4
# 2        12
# 8        22
# 5        22
# 3        23
# 9        24
# 7        24
# 6        24
# 4        24
# Name: season, dtype: int64

# %%
index = dat["season"].value_counts().index

# %%
season_lines = pd.Series(index = index)
for i in season_lines.index:
    season_lines[i] = " <N> ".join([item for sublist in dat[dat["season"] == "{0}".
                                                format(i)]["lines"].values for item in sublist])

# %%
import random

def train_uni_markov_chain(scripts):
    
    chain = {"<START>": []}
    for script in scripts:
        new_script = script.split(" ")
        chain["<START>"].append(new_script[0])
        for i in range(len(new_script)):
            if new_script[i] not in chain:
                if i == len(new_script) - 1:
                    chain[new_script[i]] = ["<END>"]
                else:
                    chain[new_script[i]] = [new_script[i+1]]
            else:
                if i == len(new_script) - 1:
                    chain[new_script[i]].append("<END>")
                else:
                    chain[new_script[i]].append(new_script[i+1])
        
    return chain

def generate_uni_new_lyrics(chain):  
    
    words = []

    words.append(random.choice(chain["<START>"]))
    
    start_word = words[0]
    while start_word != "<END>":
        next_word = random.choice(chain[start_word])
        words.append(next_word)
        start_word = next_word

    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

def train_n_markov_chain(scripts, n = 2):
    initial = []
    for i in range(n):
        if i == (n - 1):
            initial.append("<START>")
        else:
            initial.append(None)
    initial = tuple(initial)
    chain = {initial: []}
    for script in scripts:
        new_scripts = script.split(" ")
        chain[initial].append(new_scripts[0])
        for i in range(len(new_scripts)):
            if i < n - 1:
                buffer = []
                for j in range(n - i - 2):
                    buffer.append(None)
                if i == 0:
                    buffer.append("<START>")
                    buffer.append(new_scripts[i])
                else:
                    buffer = list(save[1:])
                    buffer.append(new_scripts[i])
                buffer = tuple(buffer)
                save = buffer
                chain[buffer] = [new_scripts[i+1]]
            elif (new_scripts[i-1],new_scripts[i]) not in chain:
                if i == len(new_scripts) - 1:
                    chain[(new_scripts[i-1],new_scripts[i])] = ["<END>"]
                else:
                    chain[(new_scripts[i-1],new_scripts[i])] = [new_scripts[i+1]]
            else:
                if i == len(new_scripts) - 1:
                    chain[(new_scripts[i-1],new_scripts[i])].append("<END>")
                else:
                    chain[(new_scripts[i-1],new_scripts[i])].append(new_scripts[i+1])

    return chain

def generate_n_new_lyrics(chain, n = 2):
    words = []
    initial = []
    for i in range(n):
        if i == (n - 1):
            initial.append("<START>")
        else:
            initial.append(None)
    initial = tuple(initial)
    words.append(random.choice(chain[initial]))
    buffer = list(initial[1:])
    buffer.append(words[-1])
    start_word = tuple(buffer)
    counter = 0
    save = []
    while "<END>" not in start_word:
        next_word = random.choice(chain[start_word])
        words.append(next_word)
        if counter <= n - 3:
            buffer = []
            for j in range(n - i - 3):
                buffer.append(None)
            if counter == 0:
                buffer.append("<START>")
                buffer.append(words[-2])
                buffer.append(words[-1])
                start_word = tuple(buffer)
                save = start_word
            else:
                buffer = list(save[1:])
                buffer.append(words[-1])
                start_word = tuple(buffer)
                save = start_word
            counter += 1
        else:
            start_word = list(save)[1:]
            start_word.append(words[-1])
            start_word = tuple(start_word)
        save = start_word
        print(start_word)

    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
chain = train_uni_markov_chain(season_lines.values)

# %%
print(generate_uni_new_lyrics(chain))
# Out:
# [Opening Monologue]
#  GEORGE: Why not?
#  ELAINE: Oh, you wanna go?
#  GEORGE: (bursting out a horse manure is at the street.
#  [Back to give up before is just took my name? The phone call a front desk goes back to send you can't go to Gino, he's mesmerized) I reach forward so happy with a long walk, oblivious to coordinate it B-e-n-e-s.
#  GEORGE: No.
#  (Jerry joins in.)
#  ELAINE: See, See, Van Buren Boys - his head from hand moves it.
#  GEORGE: Ttu (wipes chocolate covered in the upcoming ramifications)
#  JERRY: Well, the disease! You took him on the back to Jerry.
#  JERRY: George runs off on George) Uh, Jerry's empty and dials the Human Fund." - for aiding and (points to Mickey)
#  JACK: This is she?
#  KRAMER: I got pretty much was in an eye, as the glee club's finished their duffle bags? He's all day but runs out.)
#  (Kramer slowly along the engine running.
#  GEORGE: (checking the door; Jerry, I once that money problems.
#  [Jerry and makes a blind man you have to the importing.
#  JERRY: Oh. Big investment you don't know, it's a call. You know, you're nuts about this. It - DAY
#  KRAMER: I care about the angle: Zelda Fitzgerald, aaaand, somebody you go to talk to Jerry hand) It doesn't do you has been a show about a new personal favourite. Or, if something about it called me it's fascinating.
#  ELAINE: You know, but say this.
#  (Car crash barrier. (Elaine stretches out to Bob?" "Have a pact with you.
#  GEORGE: If you back with her)
#  (Morty sits, fighting cancer, but drops it. You know, they're real.
#  JERRY: I tell 'em on his friend so clean.
#  JERRY: I don't know.
#  RACHEL: Hi. One second... Well, you to keep this light on...
#  GEORGE: Sure.
#  GEORGE: Hey, my life, knowing it.
#  Joe, Joe DiMaggio?
#  KRAMER: Well, I don't think we have you four of yourself! Stop using that the meeting with drool coming right doing here?!
#  JERRY: Well, live in and down)
#  ELAINE: Correct.
#  [Cut back here you in?
#  HELEN: You know Newman a prop comic! Where's his friends, and wait a ticket.
#  KRAMER: YOU IDIOT.
#  (Jerry walks over to give us without this is,
#  GEORGE: It's okay okay now on."
#  ELAINE: Oh no.
#  GEORGE: Five minutes. Have you can't break up my head down at George.
#  JERRY: That's Hennigans, the Cadillac, turns and George this is it on his grip and has his psychiatrist. They're cooking all my glasses.
#  WOMAN: (noticing the scrutiny that captures the counter with props the porta potty and he's indicating someone else you took a small ceremony.
#  NEWMAN: (Pondering Kramer's for me... Jimmy's out of my father o'gimpy.
#  KRAMER: Well, that's.. Elaine!
#  KRAMER: I'd trust me.. but I didn't love. You're flesh and Louise as long I'm better to take them. I just assume not Jerry, huh.
#  KRAMER: Hey. (grabs the car go eye makeup?
#  GEORGE: Wha, what a woman who is been looking around, and exciting pilots for the beach cologne, all the cleaner admit that up?
#  ELAINE: Well... night.
#  JERRY: I haven't done it?
#  ELAINE: (Pointing at 9:00.
#  JERRY: Yeah!
#  DETECTIVE (V.O.): Mmm, Ah, you need to see the inside where you to know if you could've killed and rubs his pocket) And this is supposed to you?
#  ELAINE: Look at it. Yep.
#  JERRY: She's not all this?
#  ATTENDANT: Here we could do.
#  JERRY: They gave him against the elevator passengers exits, he call if you know what you
#  DOLL: Oh, yeah, maybe not really wrong with it?
#  JACK: Positive! This is introduced us, we'll call it might have cleaned up whilst writing your boss.
#  GEORGE: Yeah yeah
#  (Jerry knocks one of the shirttail and George)
#  JERRY: Boy, you kidding? I don't remember it up several rows of my fault?!... It - and steal another, portlier, tourist bus, the basketball game either. The hat with her mouth) I have the other men."" Do not helping.
#  KRAMER: (from the hunted becomes a pretentious woman.)
#  KRAMER: Yeah. I was broken down low cut it anywhere. Bad. 'Tis a line for coming.
#  JERRY: No. Nina.
#  JERRY: (to Neil) So, come you calling from its way up.. why no - NIGHT]
#  JERRY: Oh yeah, I just leave.
#  (Elaine hears George Costanza's house]
#  STEINBRENNER: Sure I called the store.)
#  JERRY: Tropic of levels. Misunderstanding number of skin.
#  (Elaine hurriedly gets to me thirsty. (He sits side of the swelling.
#  JERRY: (gets up with silent expressions to Florida.
#  (George and Jerry and I mean, we can't accept the baking tray of here!"
#  SID: Agency?
#  FRANK: It's a joke?
#  [George is driving the legend after a magazine. There's no big moment. They like each other. Herb and ready to get the envelope) Look at my cab.
#  SECURITY GUARD: Uh huh.
#  GEORGE: Or is what movie stunk!
#  [Lawyer's Office]
#  JERRY: I just waiting list in my milk and departures. I feel my breasts!
#  GEORGE: It's stuck in there.
#  JERRY: (To George) Daphne. I know, they know?!
#  JERRY: Oh, the result of hosing the wrong message. I won't have to me. I'm homeless! I'm going to be an excape, then it's the most expensive item on the plane ticket)
#  ELAINE: Mmm, yeah. Actually, we go.
#  (George answers it.)
#  MAN2: Back on 86th street, then Aaron saying 'Son of total squares.
#  MR. ROSS: (Still trying to see them made me lug it was the 'Vincent' label to the car is a question.
#  ELAINE: What's the machine out of George's questions, bleh bleh....
#  GEORGE: Well, it at George) Have you embellish on his chance) Well, she invites me in his chance) Well, didn't get the car got along with Steven is your head. But, I, I don't think I know. You know, throughout North Dakota is cavity time.
#  JERRY: this house.
#  JERRY: She's really bad.
#  [Setting: Jerry's apartment.]
#  DRIVER: Alright! Back issues of him?
#  KRAMER: Well, I got it.
#  KRAMER: Cars are making a career day?
#  GEORGE: Yes ... so I'm not recently. He looks around)
#  The ocean called.
#  SOUP NAZI: You? That's probably just tendencies. They're all here.
#  JERRY: But I hope I'm keeping this.
#  ELAINE: Oh, Brett. I got you gonna order of coffee, that's right. Oh, by to leave.
#  JERRY: Yes, he have a year did I got my door. George too) That stinks!
#  ELAINE: Sorry.
#  [George and my God! Is anything there looks after the couch". Apparently, a kiss? Was she can be embarrassed acknowledgement smiles.) Where's the guy's friend. (Newman brakes in the building looking gloomy. Jerry a second, just came over there, done with the parking spot where did you go, people, Timmy, they're sick.
#  JERRY: Oh, it's not.
#  GLADYS: Do I see him a look at the "Off-track betting" office. Nip! ... any idea of my head to you. Now, Frank, this trial is pushed open doorway holding the driver and Union Turnpike.
#  GEORGE: "Ha..harrr."
#  BOY: Moors.
#  GEORGE: Five-thousand? Why do that?". I tolerate dissent. Stirring the law requires you doing?
#  MORTY: Hello Jerry, I took your department stores..
#  JERRY: The A-Team!
#  % The Coffee shop]
#  (Kramer swerves the bathroom.)
#  JERRY: I don't know this jacket, and Maestro bows. Picking up my bag to Richard Nixon! Nixon leaving soon.
#  JERRY: Uh, no. I'm a few minutes.
#  ELAINE: Why not?
#  ELAINE: I'm just thought...
#  GEORGE: Yeah.
#  (The waitress finally made a song."
#  JERRY: No. So, what do that dot?
#  GEORGE: I'm gonna go.
#  GEORGE: All because we haven't seen you a glance, then starts rehearsal tonight at the way, Jerry.
#  (Simon walks in.]
#  JERRY: Amazing Technicolor Dreamcoat.
#  GEORGE: Hey buddy. It's my boyfriend.
#  ELAINE: I just wrap it come down the redwood benches, washcloth to tell me get your hands!
#  BABU: No child is impressive Mandelbaum condo. Morty takes the book.)
#  NEWMAN: Well, I say, ""You have some friends here.
#  SLIPPERY PETE: It lasts three o'clock in stone.
#  GINO: No.
#  JERRY: Oh yeah, so?
#  ELAINE: It's Susan gestures get divorced thirty minutes to any sense. You don't think he's the window?
#  GEORGE: Clock over to lady friend about ten, so found the same thing.
#  ([At night, George drives away.)
#  (MARTIN leaves laughing. Jerry and stay here.
#  JERRY: Ah, don't go and that on purpose?
#  HAROLD: (to Jerry gives Jerry walks up)
#  GEORGE: Because when someone's using a complete hack. I'm down.
#  KRAMER: Well, good observations, but their lives.
#  JERRY: Well I, I just bought me an early in your pants wooshing?
#  [Closing monologue]
#  JERRY: Kramer, George, do it.
#  KRAMER: Oooh, a kind of fishing pole away with them.
#  GEORGE: I wanna miss them. (warming to the endless parade of some Tang?"
#  [Jerry's apartment]
#  GEORGE: She looks O.K. And he forgets his tongue)
#  NEWMAN: ( hangs up; he hasn't he? I don't keep you know. And, in shock) what's the same human being. The woman in the trunk, nine west side of those and can travel gym or anything. What's wrong license and David Puddy answers the money. What follows Morty and sees another subway and walks to a parked here.
#  MIKE: (desperate) I'll tell me.
#  (George enters.)
#  KRAMER: Con dios? Well, ,I'm going to me what that judgment, someone wasn't you. You're gonna let me that to you! Turn in? Yes?
#  GEORGE: How do it?
#  HELEN: I was pregnant. You've got now that he also going to bring it tonight?
#  Wx: Would you saw that they can't believe the table) What're you make Elaine is staying at]
#  JERRY: I was in there?
#  JERRY: Yeah, he's a conservative estimate. It's George. Ever notice you’ve been attracted to the horn.
#  ALICIA: Yeah.
#  (George puts the two o'clock.
#  JERRY: Why should go.
#  MEMBER 2: Mmm, Mmm, Mmmmm, Mmmm, Mmm, good.
#  TIM: (pulling out of the mail?
#  GEORGE: Yeah.
#  ELAINE: Chicken Gumbo, or any way over to 80%. No I might.
#  KRAMER (mouths the neck hole thing. I love ya.
#  GEORGE: a big one that Elaine?
#  CARRIE:Would you tell her face. It came up, juices flowing, cascading hair.
#  LEO: And every one's got a booth.)
#  ELAINE: (thinking to see any tissues from out some business elsewhere. And I know, maybe I can get moving. Jerry a waiter's tray): I was a complete idiot! You know.
#  JERRY: Are you even know Nina.
#  James Kimbrough.
#  KRAMER: You put a great seats behind the box from the balloon. If it's the table where could get out.
#  KRAMER: Well it's nothing.
#  GUILLERMO: What are you mean I'm just a pencil comes in.)
#  GEORGE: Oh, I threw that one?
#  GEORGE: That's what the first visit. Elaine said it up)
#  KRAMER: Aw, all I think about my God you should be carefully putting on here. I'll be on a lock.
#  KRAMER: That's a Riconic relationship.""
#  MORTY: You like you're gonna grab a confused looks)
#  ESTELLE: Since my face.
#  JERRY: It's just came down, and he just friends.
#  JERRY: Mmm. De-lish.
#  DETECTIVE #2 (rushing to apologize.
#  GEORGE: Yeah. I didn't appreciate your major?
#  JERRY: Hello?
#  % Off-screen, we are doing later? You only way to be good spot. (starts acting technique is scratching Kramer's door.]
#  (Jerry has spotted taking advantage of the envelope there.
#  JERRY: No, it's there!"
#  TESTIKOV: Yeah, Yeah...Why, is a good behavior, well
#  JERRY: Nope. You?
#  ELAINE: Yeah, well, things are gonna eat?
#  KRAMER: Did she by planets, asteroids...
#  JERRY: Yeah yeah.
#  JERRY: Oh, here for hand and I, but you wanna know people...and I ah.. (George answers the car only' spots, horns to the scotch my underwear. Because we're eating fish. It's good, really nailed that they could play one of the fall off back to hear what about it?
#  ELAINE: But from Jerry) Who the broker send you change your pants on?
#  JERRY: (to Claire) Now, I think she fell swoop you've ever seen hanging open the door is telling George enter Jerry's poker face.
#  JOYCE: Did we thought you and I *love* with that?
#  KRAMER: ...F, E, I, felt, pretty disappointed.
#  ELAINE: After one of the table) Oh, she say?
#  JEAN-PAUL: I'm a security guard. What kind of pretending to George.)
#  ELAINE: I-cu-di-ge--You think so.
#  (Carol reappears, followed by the master of customers.
#  ELAINE: It's amazing.
#  GEORGE: Excuse me have said that would be sweating through this thing about the dentist?
#  GEORGE: Elaine.
#  JERRY: What is all the Latham County Blood .......................... Poppie see 'em.
#  GEORGE: Karen.
#  JERRY: No, I had gotten into the expression comes out of paper towel on his hand)
#  JERRY: What?
#  (Jerry is she was disgusting.
#  WOMAN: Where are all on a load of us out.
#  ELAINE: (sharp) I'll give you."
#  KRAMER: Understand?
#  ELAINE: It's not family.
#  MEL: He seems unlikely.
#  JERRY: Well, it's over.'
#  GEORGE: The End
#  HELEN: I know.
#  ELAINE: Why do you believe it?
#  MARYEDITH: Come on, let's go.
#  KRAMER: No thanks. (turns to Pavorotti, "Teach me on my head?
#  JERRY: (looking towards door)
#  GEORGE: Hey, Lainey, wanna see Elaine hits me-- it's Klompus.
#  JERRY: Yeah, yeah, some distaste.)
#  KATY: You'd better get Testikov about stone washing? You planted it.
#  JERRY: All right.
#  ELAINE: (with Kramer)yooooouuuuuuu..
#  JERRY: Yeah. Did you doctor.
#  MAN: (pointing) Oh, I just does. You can get the fish?
#  (At this, a good home talking about it.. to soften people steal.
#  (Elaine opens it, I thought you have you later.
#  (Poppie comes up to Mr. Wilhelm is The End

# %%
chain = train_n_markov_chain(season_lines.values,3)

# %%
print(generate_n_new_lyrics(chain,3))
# Out:
# ('<START>', 'INT.', 'COMEDY')
# ('INT.', 'COMEDY', 'CLUB')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-191-fefa45bf69ab> in <module>
# ----> 1 print(generate_n_new_lyrics(chain,3))
#
# <ipython-input-190-af5b4a0e811b> in generate_n_new_lyrics(chain, n)
#      91     save = []
#      92     while "<END>" not in start_word:
# ---> 93         next_word = random.choice(chain[start_word])
#      94         words.append(next_word)
#      95         if counter <= n - 3:
#
# KeyError: ('INT.', 'COMEDY', 'CLUB')

# %%
chain[('<START>', 'INT.', 'COMEDY')]
# Out:
# ['CLUB']
