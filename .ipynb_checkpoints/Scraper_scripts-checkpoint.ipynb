# %% [markdown]
# # Seinfeld Script Scraper
#
# ### URL : http://www.seinology.com/scripts.shtml

# %%
from lxml import html
from json import dump,loads
from requests import get
import json
import re
from dateutil import parser as dateparser
from time import sleep
import pandas as pd
from itertools import chain
import numpy as np
from bs4 import BeautifulSoup
import urllib.request
import datetime

def get_val_scores(k, c = "", score="f1"):
    model = KNeighborsClassifier(n_neighbors=k,metric='euclidean')
    pipeline = Pipeline([("vectorizer",vec),("scaler",scaler),("fit",model)])
    if score == "accuracy":
        return cross_val_score(pipeline, full_lines["lines"], y_train, 
                cv=10, scoring="accuracy").mean()
    else:
        return cross_val_score(pipeline, full_lines["lines"], y_train == c, 
                cv=10, scoring= score).mean()

# %%
def parse_sein_url(url):
    texts = ""
    response_ep = get(url)
    cleaned_response_ep = response_ep.text.replace('\x00', "")
    parser_ep = html.fromstring(cleaned_response_ep)
    return parser_ep.xpath(".//p//font//text()")

def clean_text(text):
    episode_info = {}
    series_text = pd.Series(text).str.replace("\xa0","")
    clean_text = series_text.str.replace("(\n|\t)","")
    episode_info["title"] = clean_text[0]
    episode_info["chronology"] = clean_text[1]
    episode_info["date"] = clean_text[2]
    episode_info["etc"] = clean_text[3]
    if episode_info["etc"] != '':
        if episode_info["title"] == 'Episode 45 - The Wallet (1)':
            episode_info["writer"] = clean_text[6]
            episode_info["director"] = clean_text[7]
        elif episode_info["title"] == "Originally Transcribed by unknown":
            episode_info["title"] = clean_text[2]
            episode_info["chronology"] = clean_text[3]
            episode_info["date"] = clean_text[4]
            episode_info["etc"] = ''
            episode_info["writer"] = clean_text[5]
            episode_info["director"] = clean_text[6]
        else:
            episode_info["writer"] = clean_text[5]
            episode_info["director"] = clean_text[6]
    else:
        episode_info["writer"] = clean_text[4]
        episode_info["director"] = clean_text[5]
    return episode_info

def extract_text(text):
    series_text = pd.Series(text)
    clean_text = series_text.str.replace("(\xa0|\n|\t)","")
    clean_text = clean_text.str.replace("\x91","'")
    clean_text = clean_text.str.replace("\x92","'")
    clean_text = clean_text.str.replace("\x93",'""')
    clean_text = clean_text.str.replace("\x94",'""')
    clean_text = clean_text.str.replace("\x96",'-')
    start_script = clean_text[clean_text.str.contains("====")].index[0] + 1
    lines = clean_text.iloc[start_script:]
    clean_lines = lines[lines != ""]
    return clean_lines.tolist()

def extract_cast_lines(a_list,cast_member):
    cast_member = cast_member.upper()
    if cast_member == "KRAMER":
        return [i for i in a_list if "{0}:".format(cast_member) in i or "KESSLER:" in i]
    elif cast_member == "ETC":
        return [i for i in a_list if ("GEORGE:" not in i) and ("ELAINE:") not in i and ("JERRY:" not in i) and ("KRAMER:" not in i) and ("KESSLER:" not in i) and ("NEWMAN:" not in i)]
    else:
        return [i for i in a_list if "{0}:".format(cast_member) in i]

# %% [markdown]
#     """full_lines["speaker"] = (full_lines["speaker"].str.replace("'.*$","").str.replace("&.*$","").
#      str.replace("\(.*$","").str.replace("\[.*$","").str.split("(/|\+|&|and|AND|,)",expand=True).
#      apply(lambda x : list(x.dropna().astype(str)),axis = 1))"""
#
# """    full_lines = full_lines[~((full_lines["speaker"] == "/") | (full_lines["speaker"] == "+") |
# (full_lines["speaker"] == "&") | (full_lines["speaker"] == "and" ) |
# (full_lines["speaker"] == "AND") | (full_lines["speaker"] == ",") | (full_lines["speaker"] == ""))]"""
#
# """full_lines.loc[~((full_lines["speaker"] == "JERRY") | (full_lines["speaker"] =="ELAINE") |
#     (full_lines["speaker"] == "KRAMER") | (full_lines["speaker"] =="GEORGE") |
#     (full_lines["speaker"] =="NEWMAN") | (full_lines["speaker"] == "JERRY") |
#     (full_lines["speaker"] =="FRANK")),["speaker"]] = "ETC""""

# %%
def clean_data(series):
    series = series.str.lower()
    series = series.str.replace("\n","")
    series = series.str.replace("\r","")
    series = series.str.replace("-"," ")
    series = series.str.replace("[^\w\s]"," ")
    return series

def explode(df, lst_cols, fill_value=''):
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
        
    idx_cols = df.columns.difference(lst_cols)

    lens = df[lst_cols[0]].str.len()

    if (lens > 0).all():
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]

# %%
response = get("http://www.seinology.com/scripts-english.shtml")
cleaned_response = response.text.replace('\x00', "")

parser = html.fromstring(cleaned_response)

episodes = {}
regexp = re.compile(r'\d.shtml')
for i in parser.xpath('.//a'):
    try:
        if regexp.search(i.attrib["href"]):
            if i.text == None:
                episodes[i.xpath(".//font")[0].text] = "http://www.seinology.com/{0}".format(i.attrib["href"])
            else:
                episodes[i.text] = "http://www.seinology.com/{0}".format(i.attrib["href"])
    except:
        x = 1
        
df = pd.DataFrame(list(episodes.items()),columns=["Episode","URL"])

# %%
df["text"] = df["URL"].apply(parse_sein_url)
text_info = pd.DataFrame(df["text"].apply(clean_text))["text"].apply(pd.Series)

# %%
dat = df.join(text_info)
dat.loc[82,"writer"] = "Larry Charles"
dat.loc[81:82,"director"] = "Tom Cherones"

# %%
dat["lines"] = dat["text"].apply(extract_text)

# %%
dat["jerry_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"JERRY"))
dat["elaine_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"ELAINE"))
dat["kramer_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"KRAMER"))
dat["george_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"GEORGE"))
dat["newman_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"NEWMAN"))
dat["etc_lines"] = dat["lines"].apply(lambda x : extract_cast_lines(x,"etc"))

# %%
dat["date"] = dat["date"].str.replace("Broadcast date: ","")

# %%
dat["date"] = pd.to_datetime(dat['date'])

# %%
dat[["code","season","episode"]] = (dat["chronology"].
                                    str.split("(season|episode[^ ]*) ",
                                              expand=True).drop([1,3],axis=1))

# %%
dat["code"] = dat["code"].str.replace("(pc:|,)","")

# %%
dat["season"] = dat["season"].str.replace("(season |,)","")

# %%
dat["writer"] = (dat["writer"].
                 str.replace("(Written By |Written by |Written by: )","").
                 str.replace("( and |, | / Story By | & )",",").
                 str.split(","))

# %%
dat["director"] = (dat["director"].str.replace("(Directed By |Directed by |Story by )","").
                 str.replace("( & |,| and |, |Part 2 Written by )",",").
                 str.split(","))

# %%
explode_dir = explode(dat,"director")
explode_writ = explode(dat,"writer")

# %%
explode_writ["writer"].str.strip().value_counts().head()
# Out:
# Larry David       58
# Peter Mehlman     21
# Larry Charles     20
# Jerry Seinfeld    18
# Alec Berg         14
# Name: writer, dtype: int64

# %%
explode_dir["director"].str.strip().value_counts().head()
# Out:
# Andy Ackerman    84
# Tom Cherones     77
# Larry David       3
# Peter Mehlman     3
# Darin Henry       2
# Name: director, dtype: int64

# %%
dat.loc[0,"season"] = "Pilot"

# %%
dat["season"] = dat["season"].str.strip()

# %%
dat["season"].value_counts().sort_values("index")
# Out:
# Pilot     1
# 1         4
# 2        12
# 5        22
# 8        22
# 3        23
# 4        24
# 9        24
# 6        24
# 7        24
# Name: season, dtype: int64

# %%
index = dat["season"].value_counts().index

# %%
season_lines = pd.Series(index = index)
for i in season_lines.index:
    season_lines[i] = dat[dat["season"] == "{0}".format(i)]["lines"].str.join(" <N> ").values

# %%
import random

def train_uni_markov_chain(scripts1):
    
    chain = {"<START>": []}
    for scripts in scripts1:
        for script in scripts:
            new_script = script.split(" ")
            chain["<START>"].append(new_script[0])
            for i in range(len(new_script)):
                if new_script[i] not in chain:
                    if i == len(new_script) - 1:
                        chain[new_script[i]] = ["<END>"]
                    else:
                        chain[new_script[i]] = [new_script[i+1]]
                else:
                    if i == len(new_script) - 1:
                        chain[new_script[i]].append("<END>")
                    else:
                        chain[new_script[i]].append(new_script[i+1])

    return chain

def generate_uni_new_script(chain):  
    
    words = []

    words.append(random.choice(chain["<START>"]))
    
    start_word = words[0]
    while start_word != "<END>":
        next_word = random.choice(chain[start_word])
        words.append(next_word)
        start_word = next_word

    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

def train_n_markov_chain(scripts1, n = 2):
    for scripts in scripts1:
        initial = []
        for i in range(n):
            if i == (n - 1):
                initial.append("<START>")
            else:
                initial.append(None)
        initial = tuple(initial)
        chain = {initial: []}
        for script in scripts:
            new_scripts = script.split(" ")
            chain[initial].append(new_scripts[0])
            for i in range(len(new_scripts)):
                lookup = []
                for j in range(n):
                    lookup.append(new_scripts[i - n + j + 1])
                lookup = tuple(lookup)
                if i < n - 1:
                    buffer = []
                    for j in range(n - i - 2):
                        buffer.append(None)
                    if i == 0:
                        buffer.append("<START>")
                        buffer.append(new_scripts[i])
                    else:
                        buffer = list(save[1:])
                        buffer.append(new_scripts[i])
                    buffer = tuple(buffer)
                    save = buffer
                    chain[buffer] = [new_scripts[i+1]]
                elif lookup not in chain:
                    if i == len(new_scripts) - 1:
                        chain[lookup] = ["<END>"]
                    else:
                        chain[lookup] = [new_scripts[i+1]]
                else:
                    if i == len(new_scripts) - 1:
                        chain[lookup].append("<END>")
                    else:
                        chain[lookup].append(new_scripts[i+1])

    return chain

def generate_n_new_script(chain, n = 2):
    words = []
    initial = []
    for i in range(n):
        if i == (n - 1):
            initial.append("<START>")
        else:
            initial.append(None)
    initial = tuple(initial)
    words.append(random.choice(chain[initial]))
    buffer = list(initial[1:])
    buffer.append(words[-1])
    start_word = tuple(buffer)
    counter = 0
    save = []
    while "<END>" not in start_word:
        next_word = random.choice(chain[start_word])
        words.append(next_word)
        if counter <= n - 3:
            buffer = []
            for j in range(n - counter - 3):
                buffer.append(None)
            if counter == 0:
                buffer.append("<START>")
                buffer.append(words[-2])
                buffer.append(words[-1])
                start_word = tuple(buffer)
                save = start_word
            else:
                buffer = list(save[1:])
                buffer.append(words[-1])
                start_word = tuple(buffer)
                save = start_word
            counter += 1
        else:
            if n == 2:
                start_word = (words[-2],next_word)
            else:
                start_word = list(save)[1:]
                start_word.append(words[-1])
                start_word = tuple(start_word)
        save = start_word

    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
chain = train_uni_markov_chain(season_lines.values)

# %%
print(generate_uni_new_script(chain))
# Out:
# [Jerry's apartment tomorrow. I'm sorry.
#  GAIL: Pfeiffer's.
#  MRS. SWEEDLER: Mr. Costanza, if it's George. Where are annoying little piece of this little performance the cause we're neighbors. What's in the bathroom for the check up the flyers off the script...
#  JERRY: Well it's all right.
#  GEORGE: You know you with a favor -- he's one step toward George, in an elevator.
#  GEORGE: You don't need more sugar revived him.
#  GEORGE: On the West 81st street. It must be seen it.
#  JERRY: I'm the larvae? They got the shirt) Look, do have room! I know. Could I,  I feel great for dinner? Why don't understand - you, hey Kramer leans back room, and greed. And I had to build a coffee or " "What kind of sauce, your table?
#  KRAMER: Oh, is it up) Great Society of you!!
#  GEORGE: Are you got to see Babu must go home from me.
#  PAMELA: Hi Kramer.
#  KRAMER: I like a whaler]
#  [Night. George's parents' cases of lobsters from Kramer's) So if they may not a dancer...or a...news woman. The whole physics of a corridor.]
#  GEORGE: I never even willing to talk to turn of prime of yourself, is it? What do drugs. So you want. Any of his hand, opens the heiress to Kramer.) I have watched Breakfast At your problem has to George is so Kramer's blood is going to coach if you'll have my job?!
#  (Izzy Jr. drives off)
#  DAPHNE: Is it?
#  GEORGE: (Sarcastic) Yes.
#  ELAINE: Yeah!
#  JERRY: I didn't want to the hold it probably gets interesting! Don't worry. I'll do you I think Kramer was here.
#  FRANK: How good kid. I never ever find a quitter, my clips, thank you here. But you doing?
#  GEORGE: You got caught. Look, I'll get in, and accusing me couple of butter so long.
#  KRAMER: Uh, sit in coach, and fell on the most room. I think this time are you well um, Newman pats him and George rejoin the door)
#  (Jerry walks by Kramer's head.)
#  VANESSA: Forget that. [Pause] Where's Neil? How much to Jerry.)
#  MR. STEINBRENNER: Uh Roy, this amazing Peterman lead a day here says 9:00.)
#  KRAMER: Well, George is about it.
#  LAB TECHNICIAN: Actually, (George is that you up?
#  (George points over to move anymore. You're not going on?!
#  KRAMER: Mornin'.
#  ELAINE: (to Kramer): Let's see, so many factors.
#  JERRY: He winces from a lotta chairs around)
#  GEORGE: All right, have ever gonna take it and gentlemen for the lack of events.
#  (The cable guy) Oh, really?
#  [Setting: Bookstore]
#  GEORGE: Right.
#  ELAINE: Can we won't go to locate Europe mostly.
#  GEORGE: Rosses.
#  GEORGE: (pauses counting) I'm, y'know... just didn't think about him pick up again.
#  JERRY: (interrupting) "Elaine got himself up so bad, it's my mind the golf clubs. (another person with Helms and crosses the head.
#  KRAMER: Hey, look it from?
#  CHRISTIE: Ahem! Are you raced him his collar and extracts a nice gesture.
#  KRAMER: Three hundred a bad at the only one I don't know. I think of Scenes with the numbers. We do likewise.
#  JERRY: Tongue?
#  JERRY: Wait a pen.
#  JERRY: Seen any minute. (astonished) You're crazy.
#  JERRY: Call Kramer. It's a bathrobe, man, you did! You just bring it start?
#  ELAINE: What?
#  GEORGE: All right, shut up!
#  BANIA: Hey buddy, I should call anymore.
#  (Mary leans on it, eventually live right now. (sets down on Seinfeld.
#  (Kramer enters)
#  KRAMER: Come on! One can get away??
#  (Nope, obviously impressed)
#  ELAINE: Where are on like this, then falls off. -- Hotsy-Totsy, Home-- Hotsy-Notsy.
#  [walking in and Gary enters. Kramer who didn't want to the door, so appealing now... It's pompous.
#  JERRY: Hey, you can go now? I didn't have B.O.!
#  HELEN: ""Quo"". Is it back in Le Baron?
#  NEWMAN: Gotta rush.
#  Maggie Egan ........................ Ticket Clerk
#  KRAMER: (stops her I'm dumb. Don't talk to I can be able to be turning tricks in there? (Points over the counter and I just like he bumped into a - I'm doing so did she just happy someone like thirty seconds!
#  (Kramer notices one who's eating the next time?
#  GEORGE: When are in twenty four individuals has the time to touch with Joe DiMaggio
#  WALKER #3: In twenty minutes!
#  [Setting: Jerry's apartment.)
#  ELLEN: Yeah, I think this is my speech?
#  ELAINE: Well how he'd go a-knockin'.
#  DIANE: How, you for it disorienting. Who is a look hungry, or you've got into, listens to talk to Pagliacci from behind a half a good spot, the money back) Umh!
#  GEORGE: Hey - Elaine and fatter version of the apartment so he crumble any order some kind).
#  MRS. S: Jerry? Jerry?! Jerry?!!
#  EVA: (whispering) I still going to see a woman and then they continue the others - he looking stunned, I'm not goin to live, where is seeing George aren't gonna put me the truth Elaine. Yes, I enjoy the sidewalk is blocked. Nothing's wrong with you get in the top of two bucks.
#  JERRY: I do?
#  (Demonstrates with Ghandhi?
#  JERRY: All right here.
#  JERRY: Oh, I for him in the car slowly towards the bedroom. Jerry and I gotta get that bad, because Kramer gives a living!
#  ELAINE: Hi daddy.
#  JERRY: I'll tell him to the counter and Hand me or two..
#  [Office complex; Levitan's office]
#  STOCK BOY: Moors.
#  GEORGE: "How's it in him. Three calzones right away, see, this Ellen rolls as they can just thought...
#  GEORGE: Yeah!
#  ELAINE: So the bodega today?
#  SIDRA: I don't believe it, and shushing them, they make a very important is that yogurt verdict is sitting, bored attendant wouldn't be honest with both of underwear, ""C'mon babe, let's go. Mail fraud.
#  JERRY: All right, I'm sorry.
#  GEORGE: If you're leaving did not like her. I'll stop off the pressure.
#  KRAMER: (Shocked at the...
#  STEINBRENNER: Woah.
#  FRANK: Gamebird?
#  GEORGE: (sensing his present.)
#  (And he finds dozens of water gun.
#  JERRY: To repeat the envelope) This is my neck hole.'
#  EXT. CAROL'S APARTMENT - I got some questions to the Hindenburg.
#  [Jerry wakes up to that I told ya.
#  JERRY: Oooh! Bay-bee *doll*!
#  GEORGE: (sets down opposite thing I think this time!)
#  KRAMER: Okay.
#  FRED: I'm tellin' you wanna go by.
#  MORTY: Hello
# 2      1  [JERRY: So I move into the centre lane, now I ...
# 3      1  [JERRY: Most men like working on things. Tools...
# 4      1  [JERRY: Went out to dinner the other night. Ch...

# %%
index = dat["season"].value_counts().index

# %%
jerry_lines = pd.Series(index = index)
for i in jerry_lines.index:
    jerry_lines[i] = dat[dat["season"] == "{0}".format(i)]["jerry_lines"].str.join(" <N> ").values

# %%
chain = train_uni_markov_chain(jerry_lines.values)

# %%
print(generate_uni_new_script(chain))
# Out:
# JERRY: Be careful here. (pointing Kramer)
#  JERRY: Hey, Kramer! The club an' I would know what happened?
#  JERRY: Well, you've gone out of your nails, that I don't have gone.
#  JERRY: Well, I'm upset, but to go out of the ketchup bottle.
#  JERRY: Oh, no idea.
#  JERRY: I don't know what was "War--What Is that will show this your sofa, and she should I told her mind.
#  JERRY: No, you didn't imagine she reached out with a turn-off, man. That doesn't like a thumb wrestle.
#  JERRY: I really open my jacket, I gotta get on you.
#  JERRY: Expect a chance she goes: "You know!
#  JERRY: (CONT'D) What do something?
#  JERRY: Five thousand.
#  JERRY: Look at the count on the key button.
#  JERRY: So it's a two-pronged effect. Firstly, the shop is so uh, he took out the mouth. (doing the heel, they found out 'Must miss'.
#  JERRY: That is on medication.
#  JERRY: Hey, where's the booth.)
#  JERRY: NO.
#  JERRY: They're moving my taste of fungicide.)
#  JERRY: The ones like the handshaking either, but you bring in my messages. (to the beach?
#  JERRY: I don't know where Elaine from that came up to Chinatown with us both arms flailing out...
#  JERRY: But we have. What is that you sure about this moment please? Karen Hanson?
#  JERRY: Yeah.
#  JERRY: She's gonna get goin' out of 242s, so fuck(bleeped)ing good.
#  JERRY: (pressing intercom) yeah?
#  JERRY: Nice to get their planet as a long were good.
#  JERRY: Oh, okay.
#  JERRY: Wait, wait to conserve, I was on the... family history?
#  JERRY: The spit out of here, Kramer? Could be back to find a second. You're a name his head could she didn't know what the Immigration Bureau, it's just want to be really I'm--
#  JERRY: Gwen! How'd it with you give it was tonight, and now...I'm going on out of me, Kramer, I bet against Kramer's face)
#  JERRY: Second of all the Park!
#  JERRY: That's even know she's having dinner invitations forthcoming.
#  JERRY: He just don't know, the ball man has something here..
#  JERRY: Yeah, think.
#  ELAINE/JERRY: Right. You mean I found Mom and the house.
#  JERRY:: C'mon Ponytail ...Get real.
#  JERRY: So are tied!
#  JERRY: Oh it's rude, and run. Took them three days!
#  JERRY: No,, but a cane?
#  JERRY: So we're here I just talking about?
#  JERRY: Don't ask you, Elaine wants to delay talking back.
#  JERRY: Do you were so you're afraid of your act all we can get together in and most he's trying to come on the nightclub of ours for all I think you're not fire today. In five percent sure.
#  JERRY: Oh, Where are you the tension) Look, Elaine a bender.
#  JERRY: Back to shake your father got this (Imitating Audrey)
#  JERRY: You know, the cemetery.
#  JERRY: I think started to be a conversation.
#  JERRY: Where's Simon? You did she has office to say that pocket. (throws out on his attitude is, the paper.
#  JERRY: Maybe he's talking about!

# %%
chain = train_n_markov_chain(jerry_lines.values,3)

# %%
print(generate_n_new_script(chain,3))
# Out:
# JERRY: Do you know what happened to them. I once went out with a girl who's left a little zip-lock-baggy of cotton-balls over at my house. I don't know what they need. I know I don't have it, I know that- You know what they need. I know I don't have it, I know that- You know what they need. I know I don't have it, I know that- You know what they need, women seem to need a lot of cotton-balls. This is the one I'm- always has been one of the single most enjoyable experiences of life. People...did you ever hear people talking about ""We should go out""? This is what they're talking about...this whole thing, we're all out now, no one is home. Not one person here is home, we're all out! There are people tryin' to find us, they don't know where we are. (on an imaginary phone) ""Did you ring?, I can't find him."" ""Where did he go?"" ""He didn't tell me where she was staying?
#  JERRY: (aside, to George) Now that was an interesting greeting, did you notice that, George?
#  JERRY: So uh, what do you think?
#  JERRY: Yeah, but how could you be so sure?
#  JERRY: No.
#  JERRY: Yeah, okay. Oh, wait a second. Oh, I forgot to clean the bathroom.
#  JERRY: Now, how could that be good?
#  JERRY: This is a person I like, it's not ""How to score on spring break"".
#  JERRY: Yeah, well...not exactly. I mean, she said, you know, she called this morning and said she had to come in for a seminar and maybe we'll get together.
#  JERRY: If my father was moving this he'd had to have a cigarette in his mouth the whole way. (as his father) 'Have you got your end?...Your end's got to come down first, easy now, drop it down...drop it down, your end's got to come down first, easy now, drop it down...drop it down, your end's got to come down.'
#  JERRY: Look, it's a very awkward situation. I don't wanna be presumptuous.
#  JERRY: All right, she said she couldn't find a decent hotel room...
#  JERRY: Yeah, well...not exactly. I mean, she said, you know, she called this morning and said she had to come in for a seminar and maybe we'll get together.
#  JERRY: Wouldn't it be great if you could ask a woman what she's thinking?
#  JERRY: You know how they do that?
#  JERRY: Shake is bad, but what if it's the two-hander? The hand on the top, the warm look in the eyes?
#  JERRY: Right.
#  JERRY: Hey, hey.
#  LAURA & JERRY: Heeeey!
#  JERRY: It's good to see you.
#  JERRY: This is my friend George.
#  JERRY: This is how you operate?
#  JERRY: Let me just wipe the sink.
#  JERRY: The dating world is a world of tension, it's a world of pain...and you know, if a woman comes over to my house, I gotta get that bathroom ready, 'cause she needs things. Women need equipment. I don't know what to do with them, I took them out, I put them on my kitchen floor like little tumbleweeds. I thought maybe the cockroaches would see it, figure this is a dead town. ""Let's move on."" The dating world is not a fun world...it's a pressure world, it's a world of pain...and you know, if a woman comes over to my house, I gotta get that bathroom ready, 'cause she needs things. Women need equipment. I don't know what they need, women seem to need a lot of areas to cover, but someone from our staff is on the scene. That's why, I think, men get frustrated, when we see women reading articles, like: ""Where to meet men?"" We're here, we are everywhere. We're honking our horns to serve you better.

# %%
person_lines = pd.melt(dat,id_vars = "code",
               value_vars=["jerry_lines","elaine_lines","george_lines","newman_lines","kramer_lines","etc_lines"])

# %%
unnest_lines = explode(person_lines,"value").reset_index().drop("index",axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
full_lines = unnest_lines[unnest_lines["value"] != ""]

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TweetTokenizer

tknzr = TweetTokenizer()

def clean_data(series):
    series = series.str.strip()
    series = series.str.replace("\n","")
    series = series.str.replace("\r","")
    series = series.str.replace("-"," ")
    series = series.str.replace("[^\w\s]","")
    series = series.str.lower()
    series = series.str.strip()
    return series

# %%
neg = pd.read_csv("negative-words.txt",sep = " "
            ,header = None,
            encoding="latin",
            names = ["words"])
pos = pd.read_csv("positive-words.txt",sep = " "
            ,header = None,
            encoding="latin",
            names = ["words"])

# %%
pos["type"] = "Positive"
neg["type"] = "Negative"

# %%
bing = pd.concat([neg,pos])

# %%
import spacy
nlp = spacy.load('fr')

# %%
full_lines["clean"] = full_lines["value"].apply(lambda x : nlp.tokenizer(x))

full_lines = (explode(full_lines,"clean"))

full_lines["clean"] = clean_data(full_lines["clean"].apply(str))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tidy_word = full_lines[full_lines["clean"] != ""]

# %%
bing = bing.drop_duplicates("words")

# %%
bing = bing.drop_duplicates("words")

lines_bing = (pd.merge(tidy_word,
                       bing,
                       how="inner",
                       left_on="clean",
                       right_on="words",
                       validate="many_to_one")
)

# %%
lines_bing["type"] = lines_bing["type"].map({"Positive":1,
                       "Negative":-1})

# %%
senti_ep = lines_bing.pivot_table(index=["code"],
                                  columns=["variable"],
                                  values = "type",
                                  aggfunc=np.sum).fillna(0)

# %%
import seaborn as sns

# %%
senti_gather = pd.melt(senti_ep.reset_index(),
        "code",
        value_vars=["jerry_lines",
                    "elaine_lines",
                    "george_lines",
                    "newman_lines",
                    "kramer_lines",
                    "etc_lines"])

# %%
senti_gather["code"] = (senti_gather["code"].
                        str.replace("&.*","")
)
senti_gather["variable"] = (senti_gather["variable"].
                            str.replace("_.*","").str.upper())

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(senti_gather, col="variable", col_wrap=3,height=10,aspect = 1)
g = g.map(plt.plot, "code", "value", marker = ".").set_titles("{col_name} Sentiment over Time",size = 30)

for ax in g.axes.flat:
    labels = ax.get_xticklabels() 
    for i,l in enumerate(labels):
        if(int(labels[i].get_text()) % 100 != 1): labels[i] = ''
    ax.set_xticklabels(labels, rotation=50) 



plt.show()

# %%
stop_words = pd.DataFrame(stopwords.words('english'),
                          columns = ["words"])

tokens_nostop = pd.merge(tidy_word,
         stop_words,how="outer",
         left_on="clean",
         right_on="words",
         indicator = True)

stop_remove = tokens_nostop[tokens_nostop["_merge"] == "left_only"]

# %%
(stop_remove[stop_remove["variable"] == "kramer_lines"]["clean"].
 value_counts().head())
# Out:
# kramer    6936
# yeah      1026
# well       825
# oh         696
# jerry      687
# Name: clean, dtype: int64

# %%
word_freq = (tidy_word.groupby(["variable", "clean"]).
             size().
             unstack("clean").
             fillna(0))

# %%
freq_given_char = (word_freq.
                   divide(word_freq.sum(axis = 1),
                          axis = 0))

# %%
freq_given_char
# Out:
# clean                0        00       000        01       07        09  \
# variable
# elaine_lines  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# etc_lines     0.000003  0.000003  0.000003  0.000003  0.00001  0.000003
# george_lines  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# jerry_lines   0.000000  0.000000  0.000006  0.000000  0.00000  0.000000
# kramer_lines  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# newman_lines  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
#
# clean                1        10   10 year       100    ...       zoomin  \
# variable                                                ...
# elaine_lines  0.000011  0.000079  0.000000  0.000011    ...     0.000000
# etc_lines     0.000432  0.000040  0.000003  0.000016    ...     0.000000
# george_lines  0.000024  0.000024  0.000000  0.000016    ...     0.000000
# jerry_lines   0.000023  0.000028  0.000000  0.000006    ...     0.000006
# kramer_lines  0.000012  0.000036  0.000000  0.000036    ...     0.000000
# newman_lines  0.000000  0.000000  0.000000  0.000000    ...     0.000000
#
# clean          zooming     zorba      zorn  zoutraph     zubin   zulevic  \
# variable
# elaine_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# etc_lines     0.000000  0.000007  0.000000  0.000000  0.000023  0.000007
# george_lines  0.000008  0.000000  0.000000  0.000000  0.000000  0.000000
# jerry_lines   0.000000  0.000000  0.000006  0.000006  0.000000  0.000000
# kramer_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# newman_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# clean               zz         à    éclair
# variable
# elaine_lines  0.000000  0.000000  0.000000
# etc_lines     0.000003  0.000000  0.000007
# george_lines  0.000000  0.000008  0.000000
# jerry_lines   0.000000  0.000006  0.000006
# kramer_lines  0.000012  0.000000  0.000000
# newman_lines  0.000000  0.000000  0.000000
#
# [6 rows x 20794 columns]

# %%
word_freq[word_freq != 0] = 1
idf = np.log(6/word_freq.sum())

tf_idf = freq_given_char * idf

# %%
tf_idf
# Out:
# clean                0        00       000        01        07        09  \
# variable
# elaine_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# etc_lines     0.000006  0.000006  0.000004  0.000006  0.000018  0.000006
# george_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# jerry_lines   0.000000  0.000000  0.000006  0.000000  0.000000  0.000000
# kramer_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# newman_lines  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# clean                1        10   10 year       100    ...      zoomin  \
# variable                                                ...
# elaine_lines  0.000002  0.000014  0.000000  0.000002    ...     0.00000
# etc_lines     0.000079  0.000007  0.000006  0.000003    ...     0.00000
# george_lines  0.000004  0.000004  0.000000  0.000003    ...     0.00000
# jerry_lines   0.000004  0.000005  0.000000  0.000001    ...     0.00001
# kramer_lines  0.000002  0.000007  0.000000  0.000007    ...     0.00000
# newman_lines  0.000000  0.000000  0.000000  0.000000    ...     0.00000
#
# clean          zooming     zorba     zorn  zoutraph     zubin   zulevic  \
# variable
# elaine_lines  0.000000  0.000000  0.00000   0.00000  0.000000  0.000000
# etc_lines     0.000000  0.000012  0.00000   0.00000  0.000041  0.000012
# george_lines  0.000014  0.000000  0.00000   0.00000  0.000000  0.000000
# jerry_lines   0.000000  0.000000  0.00001   0.00001  0.000000  0.000000
# kramer_lines  0.000000  0.000000  0.00000   0.00000  0.000000  0.000000
# newman_lines  0.000000  0.000000  0.00000   0.00000  0.000000  0.000000
#
# clean               zz         à    éclair
# variable
# elaine_lines  0.000000  0.000000  0.000000
# etc_lines     0.000004  0.000000  0.000007
# george_lines  0.000000  0.000009  0.000000
# jerry_lines   0.000000  0.000006  0.000006
# kramer_lines  0.000013  0.000000  0.000000
# newman_lines  0.000000  0.000000  0.000000
#
# [6 rows x 20794 columns]

# %%
vals = (full_lines.pivot_table(index = "code",columns = "clean",aggfunc = 'size').
 fillna(0)["women"].
 to_frame()).reset_index()

vals["code"] = vals["code"].str.replace("&.*","").str.strip()

vals["season"] = vals["code"].apply(lambda x : x[0])

# %%
import matplotlib.pyplot as plt

g = sns.catplot(x="code",y="women",hue="season",kind="swarm",data=vals)

g.axes[0][0].set_title("Usage of 'women' over Seinfeld")

for ax in g.axes.flat:
    labels = ax.get_xticklabels() 
    for i,l in enumerate(labels):
        if(int(labels[i].get_text()) % 100 != 1): labels[i] = ''
    ax.set_xticklabels(labels, rotation=50)

# %%
sns.regplot(x="code", y="women", data=vals)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
